# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
import cv2
from PIL import Image, ImageDraw, ImageFont
import random
import os
import json
import numpy as np
from IPython.display import Image as ImageDisplay, display
import string
from faker import Faker
fake = Faker('ko_KR')

def label_to_json(label_data, image_path, json_filepath, height, width):
    json_data = {
        "path": image_path,
        "outputs": {
            "object": []
        },
        "time_labeled": 1667818663351,
        "labeled": True,
        "size": {
            "width": height,
            "height": width,
            "depth": 3
        }
    }

    for parts in label_data:
        label = parts[0]
        xmin = float(parts[1])
        ymin = float(parts[2])
        xmax = float(parts[3])
        ymax = float(parts[4])
        
        json_data["outputs"]["object"].append({
            "name": str(label),
            "bndbox": {
                "xmin": xmin,
                "ymin": ymin,
                "xmax": xmax,
                "ymax": ymax
            }
        })

        with open(json_filepath, "w") as json_file:
            json.dump(json_data, json_file, indent=4)

    return json_data


def random_size(output_path, boxes):
    img = cv2.imread(output_path)

    width, height = img.shape[1], img.shape[0]
    new_img_width = random.randint(400, 1200)
    resize_factor = new_img_width/width
    new_img_height = int(height*(resize_factor))
    
    img = cv2.resize(img, (new_img_width, new_img_height))
    
    zoom = random.uniform(1,1.5)
    background = (55,100,10)
    
    new_h, new_w = int(new_img_height*zoom), int(new_img_width*zoom)
    
    ## bg_img = Image.new('RGB', (new_w, new_h), background)
    # bcfolder = "background/"
    # bc_list = os.listdir(bcfolder)
    # bg_img = Image.open('background/' + bc_list[random.randint(0, len(bc_list)-1)])
    # bg_img = bg_img.resize((new_w, new_h))
    
    # offset_w = abs(int((new_w-new_img_width)/2))
    # offset_h = abs(int((new_h-new_img_height)/2))
    
    # offset_w = offset_w + random.randint(-offset_w, offset_w)
    # offset_h = offset_h + random.randint(-offset_h, offset_h)
    
    # bg_img.paste(Image.fromarray(img), (offset_w, offset_h))
    
    # new_img = cv2.cvtColor(np.array(bg_img), cv2.COLOR_BGR2RGB)
    
    new_img = img
    offset_h, offset_w = 0,0
    
    #Boxes correction
    corrected_box = []
    for box in boxes:
        xmin = int(box[1]*resize_factor)+offset_w
        ymin = int(box[2]*resize_factor)+offset_h
        xmax = int(box[3]*resize_factor)+offset_w
        ymax = int(box[4]*resize_factor)+offset_h
        corrected_box.append(tuple([box[0], xmin, ymin, xmax, ymax]))
    
    return new_img, corrected_box

def perspective_warp(image, boxes, max_distortion=0.2):
    height, width = image.shape[:2]
    
    src_points = np.float32([[0, 0], [width, 0], [width, height], [0, height]])

    p1 = [random.randint(0, int(width*max_distortion)), random.randint(0, int(height*max_distortion))]
    p2 = [random.randint(int(width*(1-max_distortion)), width), random.randint(0, int(height*max_distortion))]
    p3 = [random.randint(int(width*(1-max_distortion)), width), random.randint(int(height*(1-max_distortion)), height)]
    p4 = [random.randint(0, int(width*max_distortion)), random.randint(int(height*(1-max_distortion)), height)]
    
    dst_points = np.float32([p1, p2, p3, p4])
    
    max_width_distortion = abs(dst_points[1][0] - dst_points[0][0]) / width - 1
    max_height_distortion = abs(dst_points[3][1] - dst_points[0][1]) / height - 1
    
    perspective_matrix = cv2.getPerspectiveTransform(src_points, dst_points)
    warped_image = cv2.warpPerspective(image, perspective_matrix, (width, height))

    corrected_box = []
    for bbox in boxes:
        bbox_points = np.float32([[[bbox[1], bbox[2]]], [[bbox[3], bbox[2]]], [[bbox[3], bbox[4]]], [[bbox[1], bbox[4]]]])
        warped_points = cv2.perspectiveTransform(bbox_points, perspective_matrix)

        warped_bbox = np.squeeze(warped_points).tolist()
        warped_bbox = [int(x) for point in warped_bbox for x in point] 
        corrected_box.append(tuple([bbox[0], warped_bbox[0], min(warped_bbox[1], warped_bbox[3]),
                                    warped_bbox[4], max(warped_bbox[5], warped_bbox[7])]))
    
    return warped_image, corrected_box

def unwarp(path):
    img = cv2.imread(path)
    GrayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    BlurredFrame = cv2.GaussianBlur(GrayImg, (5, 5), 1)
    CannyFrame = cv2.Canny(BlurredFrame, 190, 190)
    contours, _ = cv2.findContours(CannyFrame, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    ContourFrame = img.copy()
    ContourFrame = cv2.drawContours(ContourFrame, contours, -1, (255, 0, 255), 4)
    CornerFrame = img.copy()
    maxArea = 0
    w = 512
    h = int(w*0.6785)
    biggest = []
    for i in contours :
        area = cv2.contourArea(i)
        if area > 2000 :
            peri = cv2.arcLength(i, True)
            edges = cv2.approxPolyDP(i, 0.02*peri, True)
            if area > maxArea and len(edges) == 4 :
                biggest = edges
                maxArea = area
    if len(biggest) != 0 :
        CornerFrame = cv2.drawContours(CornerFrame, biggest, -1, (255, 0, 255), 25)
        biggest = biggest.reshape((4,2))
        biggestNew = np.zeros((4,1,2), dtype=np.int32)
        add = biggest.sum(1)
        biggestNew[0] = biggest[np.argmin(add)]
        biggestNew[3] = biggest[np.argmax(add)]
        diff = np.diff(biggest, axis=1)
        biggestNew[1] = biggest[np.argmin(diff)]
        biggestNew[2] = biggest[np.argmax(diff)]
        pts1 = np.float32(biggestNew)
        pts2 = np.float32([[0,0],[w,0],[0,h],[w,h]])
        matrix = cv2.getPerspectiveTransform(pts1, pts2)
        warped = cv2.warpPerspective(img, matrix, (w,h))
        
    cv2.imwrite("scan.jpg", warped)
    display(ImageDisplay('scan.jpg'))

# %%
def generate_random_data_korea():
    A_Z = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    fname = ''.join(random.choices(string.ascii_letters, k=random.randint(3, 12))).upper()
    lname = ''.join(random.choices(string.ascii_letters, k=random.randint(3, 12))).upper()
    name = f"{fname} {lname}"
    name1 = fake.name()
    address = fake.address()
    k = 0
    split = 0 #adress partiton
    for i in range(len(address)):
        if(address[i] == ' '):
            k += 1
        if(k == 2):
            split = i
            break

    sub_add1 = address[1:split]
    sub_add2 = address[split:]
    print("/n", address, "sub :", sub_add1, "---", sub_add2)
    address = f"{sub_add1}\n{sub_add2}"
    #test line: 
    dlnum1 = ''.join(random.choices('0123456789', k=2))
    dlnum2 = ''.join(random.choices('0123456789', k=6))
    dlnum3 = ''.join(random.choices('0123456789', k=2))
    dlnum = f"{dlnum1}-{dlnum2}-{dlnum3}"
    #passport_number = ''.join(random.choices(A_Z, k=1))+''.join(random.choices('0123456789', k=3))+''.join(random.choices(A_Z, k=1))+''.join(random.choices('0123456789', k=4))
    
    months = ["JAN", "FEB", "MAR", "APR", "MAY", "JUN", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC"]
    random_month = random.choice(months)
    random_month1 = random.randint(1, 12)
    random_month2 = random.randint(1, 12)
    random_month3 = random.randint(1, 12)
    random_year = random.randint(00, 99) #for date of birth
    random_year1 = random.randint(2000, 2024) #this is for issue date
    random_day = random.randint(1, 30)
    registration_num = ''.join(random.choices('0123456789', k =7))
    birthdate = f"{random_year}{random_month1}{random_day}-{registration_num}"
    expiry_date = f"{random_year1+random.randint(2,50)}.{random_month2}.{random_day}"
    issue_date = f"{random_year1}.{random_month3}.{random_day}"
    #age = str(random.randint(18, 80))
    gender = random.choice(["M", "F"])
    # photo_path = "placeholder_photo.jpg"

    return name1, dlnum, address, birthdate, expiry_date, issue_date, gender #changed passport to dlnum here
    
def create_dummy_passport(template_path, output_path):
    # Load template image
    template = Image.open(template_path)
    # get width and height 
    #width,height = template.size 
  
    # display width and height 
    #print("The height of the image is: ", height) 
    #print("The width of the image is: ", width)
    draw = ImageDraw.Draw(template)

    #width = template.width()
    #height = template.height()
    #print("the width and height are: ", width, height)
    # font_path = "/home/harshit.p1/Downloads/Ubuntu/Ubuntu-Bold.ttf" 
    font_path = "/Users/arshith/Downloads/intern_srib/Open_Sans/OpenSans-VariableFont_wdth,wght.ttf"
    font_path_kr = "/Users/arshith/Downloads/intern_srib/NanumSquareNeo/TTF/NanumSquareNeo-bRg.ttf"
    font = ImageFont.truetype(font_path, size=30)
    font_kr = ImageFont.truetype(font_path_kr, size=30)

    name, dlnum, address, birthdate, expiry_date, issue_date, gender = generate_random_data_korea() #changed passport to dl num


    # Define text positions
    text_positions = {
        #changing all positions 
        "Name": ((312, 150), name),
        #"Surname": ((430, 150), lname),
        "Num": ((312, 100), dlnum),
        "Address": ((307, 250), address),
        "Birthdate": ((307,190), birthdate),
        "ExpDate": ((460, 345), expiry_date),
        "IssueDate": ((289, 510), issue_date),
        #"Gender": ((768, 405), gender),
        #"CountryCode": ((540, 150), "KOR"),
        #"Nationality": ((430, 485), "REPUBLIC OF KOREA")
    }
    boxes = []
    for key, position in text_positions.items():
        if (key == "Name" or key == "Address") :
            #print("/n", key," next ", position[0][0], "-", position[0][1], "-", position[1])
            draw.text((position[0][0], position[0][1]-5), position[1], fill="black", font=font_kr)
            bbox = draw.textbbox((position[0][0], position[0][1]-5), position[1], font=font_kr)
            #print("/n", bbox)
            boxes.append(tuple([key])+bbox)
            #print("/n", boxes)
        else :

            #print("/n", key," next ", position[0][0], "-", position[0][1], "-", position[1])
            draw.text((position[0][0], position[0][1]-5), position[1], fill="black", font=font)
            bbox = draw.textbbox((position[0][0], position[0][1]-5), position[1], font=font)
            #print("/n", bbox)
            boxes.append(tuple([key])+bbox)
            #print("/n", boxes)
        
    # photo = Image.open(photo_path)
    # photo = photo.resize((120, 150))
    # template.paste(photo, (300, 100))
    
    image_path = output_path.replace("***", "images")+".jpg"
    json_path = output_path.replace("***", "json")+".json"
    
    template.save(image_path)
    image, corrected_box = random_size(image_path, boxes)
    if(random.randint(0,1)==1):
        image, corrected_box = perspective_warp(image, corrected_box, max_distortion=0.1)
    # for (_, xmin, ymin, xmax, ymax) in corrected_box:
    #     image = cv2.rectangle(image, (xmin, ymin), (xmax, ymax),  color=(255,0,0), thickness=1)

    label_to_json(corrected_box, image_path.split('images/')[1], json_path, image.shape[1], image.shape[0])
    cv2.imwrite(output_path.replace("***", "images")+".jpg", image)
    return image_path


def generate_images(num):
    for i in range(num):
        i = "/Users/arshith/Downloads/intern_srib/syn_trial/***/k"+str(i)
        template_path = "/Users/arshith/Downloads/intern_srib/TEMPLATES/temp_korea.jpg" 
        output_path = i
        file = create_dummy_passport(template_path, output_path)
        # display(ImageDisplay(filename=file))
        
generate_images(500)
# unwarp("synthetic_data/korea/images/0.jpg")
# Out:
# /n 강원도 김포시 봉은사1가 sub : 원도 김포시 ---  봉은사1가
# /n 경상남도 수원시 팔달구 압구정길 (서연김박리) sub : 상남도 수원시 ---  팔달구 압구정길 (서연김박리)
# /n 전라남도 평택시 역삼길 sub : 라남도 평택시 ---  역삼길
# /n 인천광역시 성북구 양재천9가 sub : 천광역시 성북구 ---  양재천9가
# /n 울산광역시 강동구 가락3가 (민지오오면) sub : 산광역시 강동구 ---  가락3가 (민지오오면)
# /n 전라남도 의정부시 역삼6거리 (종수김동) sub : 라남도 의정부시 ---  역삼6거리 (종수김동)
# /n 울산광역시 마포구 압구정길 sub : 산광역시 마포구 ---  압구정길
# /n 강원도 천안시 동남구 압구정로 (서연김면) sub : 원도 천안시 ---  동남구 압구정로 (서연김면)
# /n 세종특별자치시 남구 봉은사로 (정남우김면) sub : 종특별자치시 남구 ---  봉은사로 (정남우김면)
# /n 충청북도 금산군 선릉3가 (예진홍면) sub : 청북도 금산군 ---  선릉3가 (예진홍면)
# /n 전라북도 괴산군 도산대가 sub : 라북도 괴산군 ---  도산대가
# /n 인천광역시 서구 양재천3거리 sub : 천광역시 서구 ---  양재천3거리
# /n 인천광역시 서구 개포로 sub : 천광역시 서구 ---  개포로
# /n 부산광역시 노원구 양재천가 (예은이마을) sub : 산광역시 노원구 ---  양재천가 (예은이마을)
# /n 울산광역시 중랑구 개포길 (성호김이리) sub : 산광역시 중랑구 ---  개포길 (성호김이리)
# /n 경상남도 양주시 잠실가 (정식김최면) sub : 상남도 양주시 ---  잠실가 (정식김최면)
# /n 대전광역시 용산구 논현가 (영호강동) sub : 전광역시 용산구 ---  논현가 (영호강동)
# /n 인천광역시 동작구 오금7로 (정숙엄차마을) sub : 천광역시 동작구 ---  오금7로 (정숙엄차마을)
# /n 전라남도 화성시 오금433길 sub : 라남도 화성시 ---  오금433길
# /n 광주광역시 영등포구 영동대로 (은지김마을) sub : 주광역시 영등포구 ---  영동대로 (은지김마을)
# /n 광주광역시 강동구 논현가 sub : 주광역시 강동구 ---  논현가
# /n 인천광역시 성북구 논현6가 sub : 천광역시 성북구 ---  논현6가
# /n 강원도 의왕시 선릉로 sub : 원도 의왕시 ---  선릉로
# /n 강원도 철원군 서초중앙길 sub : 원도 철원군 ---  서초중앙길
# /n 제주특별자치도 영월군 삼성거리 sub : 주특별자치도 영월군 ---  삼성거리
# /n 경상북도 의정부시 서초대27길 (서연권읍) sub : 상북도 의정부시 ---  서초대27길 (서연권읍)
# /n 제주특별자치도 보은군 반포대거리 (영식권읍) sub : 주특별자치도 보은군 ---  반포대거리 (영식권읍)
# /n 전라남도 용인시 수지구 오금길 (경숙박김읍) sub : 라남도 용인시 ---  수지구 오금길 (경숙박김읍)
# /n 강원도 천안시 동남구 학동가 (건우문읍) sub : 원도 천안시 ---  동남구 학동가 (건우문읍)
# /n 대전광역시 종로구 석촌호수7길 (명자이면) sub : 전광역시 종로구 ---  석촌호수7길 (명자이면)
# /n 서울특별시 동작구 잠실거리 (미경김김마을) sub : 울특별시 동작구 ---  잠실거리 (미경김김마을)
# /n 강원도 의정부시 오금길 (성호한읍) sub : 원도 의정부시 ---  오금길 (성호한읍)
# /n 세종특별자치시 도봉구 영동대301로 sub : 종특별자치시 도봉구 ---  영동대301로
# /n 서울특별시 송파구 학동길 sub : 울특별시 송파구 ---  학동길
# /n 대구광역시 강남구 선릉640길 sub : 구광역시 강남구 ---  선릉640길
# /n 광주광역시 서구 역삼로 sub : 주광역시 서구 ---  역삼로
# /n 부산광역시 동구 서초중앙816길 sub : 산광역시 동구 ---  서초중앙816길
# /n 인천광역시 서대문구 서초대길 (순자김이읍) sub : 천광역시 서대문구 ---  서초대길 (순자김이읍)
# /n 충청북도 가평군 학동924거리 sub : 청북도 가평군 ---  학동924거리
# /n 전라북도 동두천시 테헤란28가 (승현윤양리) sub : 라북도 동두천시 ---  테헤란28가 (승현윤양리)
# /n 경상남도 예산군 역삼814가 sub : 상남도 예산군 ---  역삼814가
# /n 대구광역시 남구 영동대6가 sub : 구광역시 남구 ---  영동대6가
# /n 전라북도 고양시 석촌호수가 sub : 라북도 고양시 ---  석촌호수가
# /n 인천광역시 용산구 서초중앙로 sub : 천광역시 용산구 ---  서초중앙로
# /n 경상북도 서천군 서초중앙로 sub : 상북도 서천군 ---  서초중앙로
# /n 인천광역시 구로구 선릉로 (영환신김마을) sub : 천광역시 구로구 ---  선릉로 (영환신김마을)
# /n 대구광역시 동구 논현길 (영환윤동) sub : 구광역시 동구 ---  논현길 (영환윤동)
# /n 강원도 평창군 영동대가 sub : 원도 평창군 ---  영동대가
# /n 부산광역시 강동구 도산대3로 sub : 산광역시 강동구 ---  도산대3로
# /n 부산광역시 남구 서초대129거리 (현지박면) sub : 산광역시 남구 ---  서초대129거리 (현지박면)
# /n 부산광역시 중랑구 선릉4길 (은서김김읍) sub : 산광역시 중랑구 ---  선릉4길 (은서김김읍)
# /n 충청북도 양구군 봉은사8가 sub : 청북도 양구군 ---  봉은사8가
# /n 경상남도 예산군 언주624가 sub : 상남도 예산군 ---  언주624가
# /n 인천광역시 광진구 압구정길 (동현박마을) sub : 천광역시 광진구 ---  압구정길 (동현박마을)
# /n 부산광역시 중랑구 압구정0가 (광수최김리) sub : 산광역시 중랑구 ---  압구정0가 (광수최김리)
# /n 울산광역시 금천구 테헤란9로 sub : 산광역시 금천구 ---  테헤란9로
# /n 충청남도 진천군 학동1로 (수진이읍) sub : 청남도 진천군 ---  학동1로 (수진이읍)
# /n 인천광역시 마포구 학동거리 sub : 천광역시 마포구 ---  학동거리
# /n 제주특별자치도 용인시 기흥구 가락908로 sub : 주특별자치도 용인시 ---  기흥구 가락908로
# /n 경기도 안산시 테헤란거리 sub : 기도 안산시 ---  테헤란거리
# /n 인천광역시 북구 논현98길 (민수나마을) sub : 천광역시 북구 ---  논현98길 (민수나마을)
# /n 대전광역시 서구 테헤란8가 sub : 전광역시 서구 ---  테헤란8가
# /n 인천광역시 양천구 백제고분로 (건우박리) sub : 천광역시 양천구 ---  백제고분로 (건우박리)
# /n 제주특별자치도 고양시 양재천로 (종수김이마을) sub : 주특별자치도 고양시 ---  양재천로 (종수김이마을)
# /n 대전광역시 북구 도산대가 sub : 전광역시 북구 ---  도산대가
# /n 광주광역시 중랑구 도산대가 sub : 주광역시 중랑구 ---  도산대가
# /n 전라남도 양주시 논현1길 sub : 라남도 양주시 ---  논현1길
# /n 대구광역시 중랑구 양재천032길 sub : 구광역시 중랑구 ---  양재천032길
# /n 세종특별자치시 강북구 오금거리 sub : 종특별자치시 강북구 ---  오금거리
# /n 경기도 속초시 서초중앙가 (서준박신면) sub : 기도 속초시 ---  서초중앙가 (서준박신면)
# /n 세종특별자치시 강남구 잠실로 (성진임리) sub : 종특별자치시 강남구 ---  잠실로 (성진임리)
# /n 경상북도 용인시 처인구 압구정606길 (현숙박강면) sub : 상북도 용인시 ---  처인구 압구정606길 (현숙박강면)
# /n 충청북도 서천군 개포거리 sub : 청북도 서천군 ---  개포거리
# /n 부산광역시 양천구 논현가 sub : 산광역시 양천구 ---  논현가
# /n 인천광역시 서초구 봉은사길 sub : 천광역시 서초구 ---  봉은사길
# /n 전라북도 시흥시 테헤란59가 sub : 라북도 시흥시 ---  테헤란59가
# /n 전라북도 남양주시 가락14가 sub : 라북도 남양주시 ---  가락14가
# /n 대전광역시 서구 언주5로 sub : 전광역시 서구 ---  언주5로
# /n 경상북도 수원시 영통구 개포길 sub : 상북도 수원시 ---  영통구 개포길
# /n 전라북도 성남시 중원구 양재천거리 sub : 라북도 성남시 ---  중원구 양재천거리
# /n 충청북도 광주시 학동로 sub : 청북도 광주시 ---  학동로
# /n 전라북도 영월군 백제고분228로 sub : 라북도 영월군 ---  백제고분228로
# /n 울산광역시 관악구 개포가 (영식손김면) sub : 산광역시 관악구 ---  개포가 (영식손김면)
# /n 경상북도 괴산군 압구정129거리 (옥순김마을) sub : 상북도 괴산군 ---  압구정129거리 (옥순김마을)
# /n 전라남도 청양군 백제고분91거리 (영식김동) sub : 라남도 청양군 ---  백제고분91거리 (영식김동)
# /n 서울특별시 광진구 잠실348길 (도현조이면) sub : 울특별시 광진구 ---  잠실348길 (도현조이면)
# /n 부산광역시 서구 가락102거리 (상훈백읍) sub : 산광역시 서구 ---  가락102거리 (상훈백읍)
# /n 충청북도 수원시 영통구 반포대로 sub : 청북도 수원시 ---  영통구 반포대로
# /n 강원도 철원군 선릉길 (성훈이이마을) sub : 원도 철원군 ---  선릉길 (성훈이이마을)
# /n 대전광역시 양천구 테헤란088로 sub : 전광역시 양천구 ---  테헤란088로
# /n 강원도 인제군 석촌호수가 (지아류읍) sub : 원도 인제군 ---  석촌호수가 (지아류읍)
# /n 충청북도 춘천시 잠실31길 (선영이하읍) sub : 청북도 춘천시 ---  잠실31길 (선영이하읍)
# /n 세종특별자치시 금천구 양재천31가 (영순이권리) sub : 종특별자치시 금천구 ---  양재천31가 (영순이권리)
# /n 광주광역시 성북구 영동대0거리 (영수지황동) sub : 주광역시 성북구 ---  영동대0거리 (영수지황동)
# /n 광주광역시 동대문구 백제고분거리 sub : 주광역시 동대문구 ---  백제고분거리
# /n 전라북도 용인시 처인구 백제고분로 sub : 라북도 용인시 ---  처인구 백제고분로
# /n 세종특별자치시 서초구 서초대1길 sub : 종특별자치시 서초구 ---  서초대1길
# /n 강원도 포천시 역삼가 (승민조주마을) sub : 원도 포천시 ---  역삼가 (승민조주마을)
# /n 부산광역시 종로구 선릉4거리 sub : 산광역시 종로구 ---  선릉4거리
# /n 강원도 용인시 수지구 삼성가 (윤서박면) sub : 원도 용인시 ---  수지구 삼성가 (윤서박면)
# /n 경상북도 성남시 수정구 영동대239거리 (현준홍리) sub : 상북도 성남시 ---  수정구 영동대239거리 (현준홍리)
# /n 인천광역시 서대문구 서초중앙가 sub : 천광역시 서대문구 ---  서초중앙가
# /n 대전광역시 도봉구 백제고분가 sub : 전광역시 도봉구 ---  백제고분가
# /n 충청북도 속초시 학동5길 sub : 청북도 속초시 ---  학동5길
# /n 대전광역시 강서구 반포대길 sub : 전광역시 강서구 ---  반포대길
# /n 제주특별자치도 옥천군 영동대545로 sub : 주특별자치도 옥천군 ---  영동대545로
# /n 경상남도 천안시 동남구 언주로 sub : 상남도 천안시 ---  동남구 언주로
# /n 세종특별자치시 성북구 오금길 sub : 종특별자치시 성북구 ---  오금길
# /n 울산광역시 중랑구 반포대91로 (병철서면) sub : 산광역시 중랑구 ---  반포대91로 (병철서면)
# /n 서울특별시 은평구 압구정579거리 sub : 울특별시 은평구 ---  압구정579거리
# /n 부산광역시 동작구 오금길 (현숙신읍) sub : 산광역시 동작구 ---  오금길 (현숙신읍)
# /n 경상남도 오산시 석촌호수길 (우진오마을) sub : 상남도 오산시 ---  석촌호수길 (우진오마을)
# /n 광주광역시 송파구 석촌호수거리 sub : 주광역시 송파구 ---  석촌호수거리
# /n 전라남도 남양주시 개포97길 (경수주읍) sub : 라남도 남양주시 ---  개포97길 (경수주읍)
# /n 서울특별시 중구 테헤란로 (윤서지장읍) sub : 울특별시 중구 ---  테헤란로 (윤서지장읍)
# /n 광주광역시 관악구 언주045로 sub : 주광역시 관악구 ---  언주045로
# /n 인천광역시 강남구 강남대거리 (선영이면) sub : 천광역시 강남구 ---  강남대거리 (선영이면)
# /n 경상남도 양양군 강남대길 (예지김이동) sub : 상남도 양양군 ---  강남대길 (예지김이동)
# /n 세종특별자치시 광진구 도산대2로 (명자김읍) sub : 종특별자치시 광진구 ---  도산대2로 (명자김읍)
# /n 서울특별시 서대문구 학동787로 sub : 울특별시 서대문구 ---  학동787로
# /n 대구광역시 중랑구 잠실가 (성현임최읍) sub : 구광역시 중랑구 ---  잠실가 (성현임최읍)
# /n 대전광역시 구로구 개포거리 (민지최이마을) sub : 전광역시 구로구 ---  개포거리 (민지최이마을)
# /n 경기도 아산시 언주길 (경자박마을) sub : 기도 아산시 ---  언주길 (경자박마을)
# /n 경상남도 안성시 양재천로 sub : 상남도 안성시 ---  양재천로
# /n 광주광역시 양천구 삼성가 (성진이마을) sub : 주광역시 양천구 ---  삼성가 (성진이마을)
# /n 경상남도 제천시 서초대로 sub : 상남도 제천시 ---  서초대로
# /n 부산광역시 양천구 서초대거리 (수빈이동) sub : 산광역시 양천구 ---  서초대거리 (수빈이동)
# /n 세종특별자치시 관악구 개포로 sub : 종특별자치시 관악구 ---  개포로
# /n 전라남도 정선군 압구정666거리 sub : 라남도 정선군 ---  압구정666거리
# /n 강원도 양주시 강남대4가 (정순홍김읍) sub : 원도 양주시 ---  강남대4가 (정순홍김읍)
# /n 충청남도 공주시 테헤란28로 (지민김마을) sub : 청남도 공주시 ---  테헤란28로 (지민김마을)
# /n 충청남도 안산시 단원구 백제고분56가 sub : 청남도 안산시 ---  단원구 백제고분56가
# /n 부산광역시 관악구 언주0가 (민석김이면) sub : 산광역시 관악구 ---  언주0가 (민석김이면)
# /n 경상남도 금산군 서초대길 sub : 상남도 금산군 ---  서초대길
# /n 경기도 속초시 삼성451길 (예원이동) sub : 기도 속초시 ---  삼성451길 (예원이동)
# /n 경기도 이천시 반포대가 (정순이면) sub : 기도 이천시 ---  반포대가 (정순이면)
# /n 경기도 부여군 강남대가 (성현류이면) sub : 기도 부여군 ---  강남대가 (성현류이면)
# /n 충청북도 횡성군 서초중앙508거리 (진우한박마을) sub : 청북도 횡성군 ---  서초중앙508거리 (진우한박마을)
# /n 울산광역시 중구 석촌호수길 (성민심김면) sub : 산광역시 중구 ---  석촌호수길 (성민심김면)
# /n 부산광역시 동대문구 역삼3길 (미정김박동) sub : 산광역시 동대문구 ---  역삼3길 (미정김박동)
# /n 대전광역시 영등포구 압구정942로 (준서김김리) sub : 전광역시 영등포구 ---  압구정942로 (준서김김리)
# /n 경상북도 부천시 오정구 오금길 (채원조마을) sub : 상북도 부천시 ---  오정구 오금길 (채원조마을)
# /n 전라남도 양주시 도산대로 (영미김리) sub : 라남도 양주시 ---  도산대로 (영미김리)
# /n 울산광역시 동대문구 서초대로 (도윤김이읍) sub : 산광역시 동대문구 ---  서초대로 (도윤김이읍)
# /n 충청북도 논산시 학동5로 sub : 청북도 논산시 ---  학동5로
# /n 경상북도 춘천시 오금가 sub : 상북도 춘천시 ---  오금가
# /n 경상북도 음성군 서초중앙7거리 (하은김김리) sub : 상북도 음성군 ---  서초중앙7거리 (하은김김리)
# /n 부산광역시 종로구 역삼581가 sub : 산광역시 종로구 ---  역삼581가
# /n 경기도 단양군 서초중앙가 sub : 기도 단양군 ---  서초중앙가
# /n 대구광역시 남구 서초대0길 sub : 구광역시 남구 ---  서초대0길
# /n 전라남도 용인시 수지구 반포대길 (민지오리) sub : 라남도 용인시 ---  수지구 반포대길 (민지오리)
# /n 부산광역시 도봉구 양재천3로 (경숙장최읍) sub : 산광역시 도봉구 ---  양재천3로 (경숙장최읍)
# /n 대구광역시 관악구 가락45로 (은정이이면) sub : 구광역시 관악구 ---  가락45로 (은정이이면)
# /n 강원도 철원군 오금440로 (지훈김서마을) sub : 원도 철원군 ---  오금440로 (지훈김서마을)
# /n 전라남도 파주시 삼성가 (미영김면) sub : 라남도 파주시 ---  삼성가 (미영김면)
# /n 충청남도 부천시 오정구 삼성가 (도현허리) sub : 청남도 부천시 ---  오정구 삼성가 (도현허리)
# /n 서울특별시 강남구 서초대가 sub : 울특별시 강남구 ---  서초대가
# /n 경상남도 청주시 상당구 테헤란962로 sub : 상남도 청주시 ---  상당구 테헤란962로
# /n 대구광역시 성동구 테헤란거리 sub : 구광역시 성동구 ---  테헤란거리
# /n 서울특별시 양천구 학동748로 (성민문동) sub : 울특별시 양천구 ---  학동748로 (성민문동)
# /n 경상남도 파주시 서초대306로 sub : 상남도 파주시 ---  서초대306로
# /n 경상남도 평택시 삼성3길 (정자곽강읍) sub : 상남도 평택시 ---  삼성3길 (정자곽강읍)
# /n 대구광역시 영등포구 역삼0거리 sub : 구광역시 영등포구 ---  역삼0거리
# /n 대구광역시 영등포구 도산대9길 (정남박면) sub : 구광역시 영등포구 ---  도산대9길 (정남박면)
# /n 대전광역시 중랑구 도산대로 (광수이송읍) sub : 전광역시 중랑구 ---  도산대로 (광수이송읍)
# /n 경상북도 영월군 언주3가 sub : 상북도 영월군 ---  언주3가
# /n 부산광역시 은평구 강남대545가 (민서최면) sub : 산광역시 은평구 ---  강남대545가 (민서최면)
# /n 대구광역시 서대문구 서초중앙0가 sub : 구광역시 서대문구 ---  서초중앙0가
# /n 부산광역시 강동구 잠실8가 (종수김허리) sub : 산광역시 강동구 ---  잠실8가 (종수김허리)
# /n 울산광역시 용산구 논현663거리 (준혁박남마을) sub : 산광역시 용산구 ---  논현663거리 (준혁박남마을)
# /n 부산광역시 강서구 선릉8가 sub : 산광역시 강서구 ---  선릉8가
# /n 세종특별자치시 마포구 양재천9로 (서윤민이리) sub : 종특별자치시 마포구 ---  양재천9로 (서윤민이리)
# /n 강원도 동두천시 강남대가 (종수문동) sub : 원도 동두천시 ---  강남대가 (종수문동)
# /n 대구광역시 강서구 선릉거리 sub : 구광역시 강서구 ---  선릉거리
# /n 경상남도 철원군 백제고분거리 sub : 상남도 철원군 ---  백제고분거리
# /n 광주광역시 구로구 가락653가 sub : 주광역시 구로구 ---  가락653가
# /n 전라남도 수원시 장안구 봉은사950거리 sub : 라남도 수원시 ---  장안구 봉은사950거리
# /n 세종특별자치시 구로구 학동646로 sub : 종특별자치시 구로구 ---  학동646로
# /n 서울특별시 영등포구 반포대864로 sub : 울특별시 영등포구 ---  반포대864로
# /n 전라북도 고양시 논현294가 (민준안한리) sub : 라북도 고양시 ---  논현294가 (민준안한리)
# /n 울산광역시 강북구 백제고분로 sub : 산광역시 강북구 ---  백제고분로
# /n 부산광역시 강남구 영동대9거리 sub : 산광역시 강남구 ---  영동대9거리
# /n 충청북도 괴산군 도산대5길 (순자이면) sub : 청북도 괴산군 ---  도산대5길 (순자이면)
# /n 충청남도 제천시 도산대거리 sub : 청남도 제천시 ---  도산대거리
# /n 제주특별자치도 포천시 봉은사23가 (지현이마을) sub : 주특별자치도 포천시 ---  봉은사23가 (지현이마을)
# /n 대전광역시 강동구 도산대가 sub : 전광역시 강동구 ---  도산대가
# /n 경기도 보은군 가락744길 sub : 기도 보은군 ---  가락744길
# /n 부산광역시 중랑구 압구정446거리 sub : 산광역시 중랑구 ---  압구정446거리
# /n 서울특별시 송파구 역삼거리 (성현김김리) sub : 울특별시 송파구 ---  역삼거리 (성현김김리)
# /n 강원도 청양군 가락29로 (영식이이마을) sub : 원도 청양군 ---  가락29로 (영식이이마을)
# /n 경기도 서산시 선릉731거리 (재호황마을) sub : 기도 서산시 ---  선릉731거리 (재호황마을)
# /n 광주광역시 금천구 오금708거리 (영자이김면) sub : 주광역시 금천구 ---  오금708거리 (영자이김면)
# /n 대전광역시 동구 선릉로 sub : 전광역시 동구 ---  선릉로
# /n 충청남도 홍천군 논현295가 sub : 청남도 홍천군 ---  논현295가
# /n 서울특별시 노원구 반포대403길 (예지김김면) sub : 울특별시 노원구 ---  반포대403길 (예지김김면)
# /n 대전광역시 용산구 반포대908길 sub : 전광역시 용산구 ---  반포대908길
# /n 부산광역시 강북구 역삼806길 (미영박동) sub : 산광역시 강북구 ---  역삼806길 (미영박동)
# /n 부산광역시 광진구 개포382가 sub : 산광역시 광진구 ---  개포382가
# /n 전라북도 홍천군 삼성0가 (하윤박리) sub : 라북도 홍천군 ---  삼성0가 (하윤박리)
# /n 대구광역시 영등포구 반포대4길 (서윤차박읍) sub : 구광역시 영등포구 ---  반포대4길 (서윤차박읍)
# /n 충청남도 영동군 선릉18가 (지원김리) sub : 청남도 영동군 ---  선릉18가 (지원김리)
# /n 대전광역시 노원구 봉은사가 (상철장마을) sub : 전광역시 노원구 ---  봉은사가 (상철장마을)
# /n 전라남도 삼척시 양재천로 sub : 라남도 삼척시 ---  양재천로
# /n 전라남도 천안시 동남구 논현가 (지영김오마을) sub : 라남도 천안시 ---  동남구 논현가 (지영김오마을)
# /n 인천광역시 강남구 논현00거리 sub : 천광역시 강남구 ---  논현00거리
# /n 경기도 성남시 분당구 선릉30길 sub : 기도 성남시 ---  분당구 선릉30길
# /n 강원도 단양군 압구정33로 sub : 원도 단양군 ---  압구정33로
# /n 전라남도 안성시 삼성거리 sub : 라남도 안성시 ---  삼성거리
# /n 울산광역시 서구 역삼가 sub : 산광역시 서구 ---  역삼가
# /n 인천광역시 서대문구 역삼가 (민석이마을) sub : 천광역시 서대문구 ---  역삼가 (민석이마을)
# /n 전라남도 증평군 강남대87로 (성진노최면) sub : 라남도 증평군 ---  강남대87로 (성진노최면)
# /n 충청남도 음성군 석촌호수286가 sub : 청남도 음성군 ---  석촌호수286가
# /n 서울특별시 서구 강남대2거리 sub : 울특별시 서구 ---  강남대2거리
# /n 광주광역시 서구 백제고분거리 (은경김리) sub : 주광역시 서구 ---  백제고분거리 (은경김리)
# /n 울산광역시 성북구 역삼9길 (승민박마을) sub : 산광역시 성북구 ---  역삼9길 (승민박마을)
# /n 서울특별시 강남구 도산대거리 (준영박리) sub : 울특별시 강남구 ---  도산대거리 (준영박리)
# /n 경기도 용인시 가락7가 sub : 기도 용인시 ---  가락7가
# /n 강원도 영동군 테헤란거리 (정수박권읍) sub : 원도 영동군 ---  테헤란거리 (정수박권읍)
# /n 부산광역시 용산구 강남대길 sub : 산광역시 용산구 ---  강남대길
# /n 부산광역시 광진구 역삼가 (영호서이리) sub : 산광역시 광진구 ---  역삼가 (영호서이리)
# /n 대구광역시 강동구 백제고분167거리 sub : 구광역시 강동구 ---  백제고분167거리
# /n 광주광역시 남구 개포0길 (서준남최읍) sub : 주광역시 남구 ---  개포0길 (서준남최읍)
# /n 대구광역시 중구 반포대거리 (은경윤리) sub : 구광역시 중구 ---  반포대거리 (은경윤리)
# /n 대전광역시 영등포구 논현거리 sub : 전광역시 영등포구 ---  논현거리
# /n 경기도 의왕시 봉은사2거리 sub : 기도 의왕시 ---  봉은사2거리
# /n 전라남도 강릉시 가락로 sub : 라남도 강릉시 ---  가락로
# /n 전라북도 홍천군 선릉7거리 sub : 라북도 홍천군 ---  선릉7거리
# /n 대전광역시 종로구 언주로 sub : 전광역시 종로구 ---  언주로
# /n 대전광역시 용산구 반포대9가 sub : 전광역시 용산구 ---  반포대9가
# /n 서울특별시 강서구 도산대9거리 sub : 울특별시 강서구 ---  도산대9거리
# /n 경상북도 홍성군 양재천길 (은영손면) sub : 상북도 홍성군 ---  양재천길 (은영손면)
# /n 전라남도 하남시 개포6가 sub : 라남도 하남시 ---  개포6가
# /n 부산광역시 광진구 서초대거리 (정순김강면) sub : 산광역시 광진구 ---  서초대거리 (정순김강면)
# /n 충청북도 부천시 오정구 오금길 (민수김마을) sub : 청북도 부천시 ---  오정구 오금길 (민수김마을)
# /n 부산광역시 양천구 서초대거리 sub : 산광역시 양천구 ---  서초대거리
# /n 세종특별자치시 광진구 오금거리 (준영오구리) sub : 종특별자치시 광진구 ---  오금거리 (준영오구리)
# /n 광주광역시 강동구 개포길 (춘자서이동) sub : 주광역시 강동구 ---  개포길 (춘자서이동)
# /n 울산광역시 서구 언주326가 sub : 산광역시 서구 ---  언주326가
# /n 충청북도 가평군 백제고분로 (민수노윤동) sub : 청북도 가평군 ---  백제고분로 (민수노윤동)
# /n 경기도 천안시 동남구 석촌호수657거리 (진우이조읍) sub : 기도 천안시 ---  동남구 석촌호수657거리 (진우이조읍)
# /n 부산광역시 영등포구 서초중앙69로 (진우김마을) sub : 산광역시 영등포구 ---  서초중앙69로 (진우김마을)
# /n 충청북도 구리시 서초대76길 (현준손리) sub : 청북도 구리시 ---  서초대76길 (현준손리)
# /n 충청북도 동해시 삼성768로 (주원이손마을) sub : 청북도 동해시 ---  삼성768로 (주원이손마을)
# /n 충청북도 부여군 언주85길 sub : 청북도 부여군 ---  언주85길
# /n 강원도 횡성군 언주396거리 (정식이면) sub : 원도 횡성군 ---  언주396거리 (정식이면)
# /n 부산광역시 성동구 양재천38거리 sub : 산광역시 성동구 ---  양재천38거리
# /n 대전광역시 동대문구 서초중앙거리 (준영한마을) sub : 전광역시 동대문구 ---  서초중앙거리 (준영한마을)
# /n 제주특별자치도 안양시 동안구 선릉884거리 sub : 주특별자치도 안양시 ---  동안구 선릉884거리
# /n 대전광역시 성동구 양재천길 (재현이동) sub : 전광역시 성동구 ---  양재천길 (재현이동)
# /n 울산광역시 마포구 서초대6로 (지훈이마을) sub : 산광역시 마포구 ---  서초대6로 (지훈이마을)
# /n 서울특별시 동작구 봉은사17거리 (채원장이읍) sub : 울특별시 동작구 ---  봉은사17거리 (채원장이읍)
# /n 세종특별자치시 동대문구 가락로 (정식김박리) sub : 종특별자치시 동대문구 ---  가락로 (정식김박리)
# /n 충청북도 용인시 수지구 가락거리 (우진박이리) sub : 청북도 용인시 ---  수지구 가락거리 (우진박이리)
# /n 세종특별자치시 강서구 삼성로 sub : 종특별자치시 강서구 ---  삼성로
# /n 제주특별자치도 화성시 석촌호수091로 sub : 주특별자치도 화성시 ---  석촌호수091로
# /n 강원도 고성군 테헤란803로 sub : 원도 고성군 ---  테헤란803로
# /n 부산광역시 강동구 삼성4길 sub : 산광역시 강동구 ---  삼성4길
# /n 충청남도 의정부시 논현217거리 (지연박이마을) sub : 청남도 의정부시 ---  논현217거리 (지연박이마을)
# /n 세종특별자치시 북구 압구정9길 (민준이임동) sub : 종특별자치시 북구 ---  압구정9길 (민준이임동)
# /n 울산광역시 성동구 오금거리 (영수강동) sub : 산광역시 성동구 ---  오금거리 (영수강동)
# /n 제주특별자치도 홍천군 논현가 sub : 주특별자치도 홍천군 ---  논현가
# /n 대구광역시 마포구 양재천거리 (민석유이면) sub : 구광역시 마포구 ---  양재천거리 (민석유이면)
# /n 대전광역시 동구 선릉0길 (승민김마을) sub : 전광역시 동구 ---  선릉0길 (승민김마을)
# /n 충청남도 의정부시 영동대가 sub : 청남도 의정부시 ---  영동대가
# /n 충청남도 수원시 도산대길 (경희김황읍) sub : 청남도 수원시 ---  도산대길 (경희김황읍)
# /n 강원도 보은군 압구정가 sub : 원도 보은군 ---  압구정가
# /n 세종특별자치시 동구 서초중앙278가 (정희김면) sub : 종특별자치시 동구 ---  서초중앙278가 (정희김면)
# /n 광주광역시 양천구 영동대6가 sub : 주광역시 양천구 ---  영동대6가
# /n 대구광역시 광진구 잠실가 (순자박박면) sub : 구광역시 광진구 ---  잠실가 (순자박박면)
# /n 제주특별자치도 포천시 언주85길 sub : 주특별자치도 포천시 ---  언주85길
# /n 강원도 아산시 백제고분85가 sub : 원도 아산시 ---  백제고분85가
# /n 경기도 연천군 반포대거리 sub : 기도 연천군 ---  반포대거리
# /n 부산광역시 서초구 반포대가 (도현김이면) sub : 산광역시 서초구 ---  반포대가 (도현김이면)
# /n 세종특별자치시 성북구 학동661가 (혜진오마을) sub : 종특별자치시 성북구 ---  학동661가 (혜진오마을)
# /n 경상남도 정선군 압구정646로 sub : 상남도 정선군 ---  압구정646로
# /n 전라북도 동두천시 서초중앙길 sub : 라북도 동두천시 ---  서초중앙길
# /n 부산광역시 은평구 테헤란로 sub : 산광역시 은평구 ---  테헤란로
# /n 대전광역시 강남구 서초대036가 sub : 전광역시 강남구 ---  서초대036가
# /n 경상북도 가평군 논현가 sub : 상북도 가평군 ---  논현가
# /n 경상남도 연천군 테헤란051가 sub : 상남도 연천군 ---  테헤란051가
# /n 경기도 양양군 석촌호수14로 (성훈허최마을) sub : 기도 양양군 ---  석촌호수14로 (성훈허최마을)
# /n 세종특별자치시 마포구 압구정거리 sub : 종특별자치시 마포구 ---  압구정거리
# /n 경상남도 의정부시 서초중앙로 (은지허면) sub : 상남도 의정부시 ---  서초중앙로 (은지허면)
# /n 강원도 시흥시 강남대가 sub : 원도 시흥시 ---  강남대가
# /n 전라북도 논산시 가락2거리 sub : 라북도 논산시 ---  가락2거리
# /n 서울특별시 광진구 역삼2길 sub : 울특별시 광진구 ---  역삼2길
# /n 경상남도 단양군 잠실50가 (민준송마을) sub : 상남도 단양군 ---  잠실50가 (민준송마을)
# /n 광주광역시 중랑구 언주616길 sub : 주광역시 중랑구 ---  언주616길
# /n 경상남도 김포시 양재천1거리 sub : 상남도 김포시 ---  양재천1거리
# /n 제주특별자치도 양평군 서초중앙로 (미영손박마을) sub : 주특별자치도 양평군 ---  서초중앙로 (미영손박마을)
# /n 대전광역시 구로구 개포가 sub : 전광역시 구로구 ---  개포가
# /n 충청남도 태백시 서초대로 (민준나면) sub : 청남도 태백시 ---  서초대로 (민준나면)
# /n 광주광역시 종로구 논현20로 sub : 주광역시 종로구 ---  논현20로
# /n 제주특별자치도 부천시 오정구 도산대516길 (영호최권리) sub : 주특별자치도 부천시 ---  오정구 도산대516길 (영호최권리)
# /n 부산광역시 도봉구 석촌호수가 sub : 산광역시 도봉구 ---  석촌호수가
# /n 대전광역시 동작구 서초대로 sub : 전광역시 동작구 ---  서초대로
# /n 충청북도 영동군 영동대7가 sub : 청북도 영동군 ---  영동대7가
# /n 인천광역시 영등포구 반포대32길 (예지송면) sub : 천광역시 영등포구 ---  반포대32길 (예지송면)
# /n 경상남도 안양시 만안구 석촌호수009가 sub : 상남도 안양시 ---  만안구 석촌호수009가
# /n 대구광역시 서대문구 양재천38거리 sub : 구광역시 서대문구 ---  양재천38거리
# /n 대구광역시 서대문구 압구정42길 (영희서이읍) sub : 구광역시 서대문구 ---  압구정42길 (영희서이읍)
# /n 전라북도 포천시 잠실거리 sub : 라북도 포천시 ---  잠실거리
# /n 세종특별자치시 구로구 양재천433가 sub : 종특별자치시 구로구 ---  양재천433가
# /n 경상북도 수원시 오금가 (정호류김동) sub : 상북도 수원시 ---  오금가 (정호류김동)
# /n 세종특별자치시 성북구 학동8거리 sub : 종특별자치시 성북구 ---  학동8거리
# /n 경상남도 보령시 도산대0길 (정남김리) sub : 상남도 보령시 ---  도산대0길 (정남김리)
# /n 세종특별자치시 종로구 테헤란로 sub : 종특별자치시 종로구 ---  테헤란로
# /n 제주특별자치도 안양시 만안구 역삼가 (지아곽이리) sub : 주특별자치도 안양시 ---  만안구 역삼가 (지아곽이리)
# /n 인천광역시 성북구 잠실거리 sub : 천광역시 성북구 ---  잠실거리
# /n 강원도 서천군 도산대213가 (성수이리) sub : 원도 서천군 ---  도산대213가 (성수이리)
# /n 전라남도 수원시 석촌호수9길 (영철이하동) sub : 라남도 수원시 ---  석촌호수9길 (영철이하동)
# /n 부산광역시 마포구 논현가 sub : 산광역시 마포구 ---  논현가
# /n 세종특별자치시 도봉구 역삼78거리 sub : 종특별자치시 도봉구 ---  역삼78거리
# /n 경기도 안양시 봉은사080로 (주원김면) sub : 기도 안양시 ---  봉은사080로 (주원김면)
# /n 경상북도 이천시 개포15길 (예준이이면) sub : 상북도 이천시 ---  개포15길 (예준이이면)
# /n 인천광역시 양천구 서초대8길 (미경서류리) sub : 천광역시 양천구 ---  서초대8길 (미경서류리)
# /n 울산광역시 금천구 개포로 (재현백마을) sub : 산광역시 금천구 ---  개포로 (재현백마을)
# /n 전라북도 천안시 동남구 압구정로 sub : 라북도 천안시 ---  동남구 압구정로
# /n 제주특별자치도 안양시 동안구 논현거리 (민재윤이면) sub : 주특별자치도 안양시 ---  동안구 논현거리 (민재윤이면)
# /n 광주광역시 서대문구 삼성33길 sub : 주광역시 서대문구 ---  삼성33길
# /n 강원도 부천시 원미구 서초중앙0거리 (윤서박동) sub : 원도 부천시 ---  원미구 서초중앙0거리 (윤서박동)
# /n 충청남도 천안시 동남구 테헤란44로 sub : 청남도 천안시 ---  동남구 테헤란44로
# /n 경기도 괴산군 반포대로 sub : 기도 괴산군 ---  반포대로
# /n 세종특별자치시 관악구 서초대9거리 (정자유면) sub : 종특별자치시 관악구 ---  서초대9거리 (정자유면)
# /n 충청북도 화성시 서초중앙거리 sub : 청북도 화성시 ---  서초중앙거리
# /n 인천광역시 용산구 백제고분가 sub : 천광역시 용산구 ---  백제고분가
# /n 세종특별자치시 동구 영동대길 sub : 종특별자치시 동구 ---  영동대길
# /n 인천광역시 남구 강남대거리 sub : 천광역시 남구 ---  강남대거리
# /n 경상남도 연천군 양재천거리 sub : 상남도 연천군 ---  양재천거리
# /n 경상남도 평창군 도산대0길 (윤서박마을) sub : 상남도 평창군 ---  도산대0길 (윤서박마을)
# /n 제주특별자치도 계룡시 서초중앙가 sub : 주특별자치도 계룡시 ---  서초중앙가
# /n 제주특별자치도 증평군 선릉5거리 sub : 주특별자치도 증평군 ---  선릉5거리
# /n 강원도 영동군 선릉로 sub : 원도 영동군 ---  선릉로
# /n 경상북도 단양군 서초대4거리 (영환이이마을) sub : 상북도 단양군 ---  서초대4거리 (영환이이마을)
# /n 전라남도 양평군 양재천42길 (명숙오신읍) sub : 라남도 양평군 ---  양재천42길 (명숙오신읍)
# /n 광주광역시 금천구 논현992길 (미숙양리) sub : 주광역시 금천구 ---  논현992길 (미숙양리)
# /n 경상북도 용인시 수지구 영동대815길 (하은김손리) sub : 상북도 용인시 ---  수지구 영동대815길 (하은김손리)
# /n 대구광역시 구로구 선릉6가 sub : 구광역시 구로구 ---  선릉6가
# /n 인천광역시 서초구 양재천12길 (현준김정리) sub : 천광역시 서초구 ---  양재천12길 (현준김정리)
# /n 부산광역시 종로구 백제고분18길 sub : 산광역시 종로구 ---  백제고분18길
# /n 제주특별자치도 천안시 동남구 백제고분764로 (하은오김마을) sub : 주특별자치도 천안시 ---  동남구 백제고분764로 (하은오김마을)
# /n 울산광역시 금천구 서초대거리 sub : 산광역시 금천구 ---  서초대거리
# /n 광주광역시 북구 영동대922가 sub : 주광역시 북구 ---  영동대922가
# /n 강원도 청주시 청원구 언주로 (정숙안박마을) sub : 원도 청주시 ---  청원구 언주로 (정숙안박마을)
# /n 충청북도 삼척시 반포대39로 (지후나김읍) sub : 청북도 삼척시 ---  반포대39로 (지후나김읍)
# /n 강원도 음성군 오금4가 (수빈김리) sub : 원도 음성군 ---  오금4가 (수빈김리)
# /n 부산광역시 강동구 언주37거리 (준호이마을) sub : 산광역시 강동구 ---  언주37거리 (준호이마을)
# /n 강원도 안산시 상록구 역삼111가 sub : 원도 안산시 ---  상록구 역삼111가
# /n 대전광역시 성북구 선릉가 sub : 전광역시 성북구 ---  선릉가
# /n 충청남도 화성시 선릉474가 (민서김면) sub : 청남도 화성시 ---  선릉474가 (민서김면)
# /n 인천광역시 북구 언주69로 sub : 천광역시 북구 ---  언주69로
# /n 광주광역시 도봉구 서초대로 (지현이마을) sub : 주광역시 도봉구 ---  서초대로 (지현이마을)
# /n 경기도 단양군 역삼거리 sub : 기도 단양군 ---  역삼거리
# /n 대구광역시 구로구 삼성950거리 sub : 구광역시 구로구 ---  삼성950거리
# /n 부산광역시 용산구 테헤란가 (시우서박리) sub : 산광역시 용산구 ---  테헤란가 (시우서박리)
# /n 경기도 금산군 압구정00가 sub : 기도 금산군 ---  압구정00가
# /n 대전광역시 광진구 삼성가 (영진김마을) sub : 전광역시 광진구 ---  삼성가 (영진김마을)
# /n 서울특별시 금천구 역삼438거리 (영미김김면) sub : 울특별시 금천구 ---  역삼438거리 (영미김김면)
# /n 경상남도 서산시 개포길 sub : 상남도 서산시 ---  개포길
# /n 경기도 성남시 중원구 백제고분2거리 (지후한이마을) sub : 기도 성남시 ---  중원구 백제고분2거리 (지후한이마을)
# /n 전라남도 안산시 역삼6로 sub : 라남도 안산시 ---  역삼6로
# /n 대구광역시 영등포구 강남대8로 sub : 구광역시 영등포구 ---  강남대8로
# /n 제주특별자치도 강릉시 개포04길 (재호오이리) sub : 주특별자치도 강릉시 ---  개포04길 (재호오이리)
# /n 광주광역시 서초구 강남대924가 (영식이동) sub : 주광역시 서초구 ---  강남대924가 (영식이동)
# /n 울산광역시 양천구 서초중앙가 sub : 산광역시 양천구 ---  서초중앙가
# /n 인천광역시 양천구 개포764길 sub : 천광역시 양천구 ---  개포764길
# /n 경기도 옥천군 언주로 sub : 기도 옥천군 ---  언주로
# /n 울산광역시 관악구 오금거리 sub : 산광역시 관악구 ---  오금거리
# /n 대전광역시 강동구 압구정길 (지민윤한동) sub : 전광역시 강동구 ---  압구정길 (지민윤한동)
# /n 인천광역시 도봉구 압구정2길 sub : 천광역시 도봉구 ---  압구정2길
# /n 광주광역시 도봉구 가락거리 (광수손김읍) sub : 주광역시 도봉구 ---  가락거리 (광수손김읍)
# /n 울산광역시 동구 역삼가 (동현김박마을) sub : 산광역시 동구 ---  역삼가 (동현김박마을)
# /n 제주특별자치도 구리시 석촌호수로 sub : 주특별자치도 구리시 ---  석촌호수로
# /n 경상북도 화성시 선릉길 sub : 상북도 화성시 ---  선릉길
# /n 인천광역시 용산구 잠실가 (주원이이읍) sub : 천광역시 용산구 ---  잠실가 (주원이이읍)
# /n 전라북도 안산시 상록구 영동대길 sub : 라북도 안산시 ---  상록구 영동대길
# /n 부산광역시 강동구 언주로 (수빈임김동) sub : 산광역시 강동구 ---  언주로 (수빈임김동)
# /n 경기도 광주시 반포대거리 (정수박면) sub : 기도 광주시 ---  반포대거리 (정수박면)
# /n 부산광역시 송파구 백제고분582거리 (서연장읍) sub : 산광역시 송파구 ---  백제고분582거리 (서연장읍)
# /n 강원도 평창군 양재천67로 (채원이리) sub : 원도 평창군 ---  양재천67로 (채원이리)
# /n 광주광역시 성북구 잠실29가 sub : 주광역시 성북구 ---  잠실29가
# /n 부산광역시 관악구 서초중앙0가 (지민이마을) sub : 산광역시 관악구 ---  서초중앙0가 (지민이마을)
# /n 서울특별시 양천구 선릉로 sub : 울특별시 양천구 ---  선릉로
# /n 서울특별시 성북구 영동대1거리 sub : 울특별시 성북구 ---  영동대1거리
# /n 서울특별시 강동구 영동대길 sub : 울특별시 강동구 ---  영동대길
# /n 경상남도 과천시 반포대0거리 (영자김동) sub : 상남도 과천시 ---  반포대0거리 (영자김동)
# /n 세종특별자치시 도봉구 백제고분747가 sub : 종특별자치시 도봉구 ---  백제고분747가
# /n 경상남도 삼척시 삼성길 sub : 상남도 삼척시 ---  삼성길
# /n 제주특별자치도 보령시 서초대9거리 sub : 주특별자치도 보령시 ---  서초대9거리
# /n 광주광역시 노원구 반포대7길 (성호이면) sub : 주광역시 노원구 ---  반포대7길 (성호이면)
# /n 세종특별자치시 용산구 서초대0가 sub : 종특별자치시 용산구 ---  서초대0가
# /n 대구광역시 동구 언주거리 (지원허김면) sub : 구광역시 동구 ---  언주거리 (지원허김면)
# /n 인천광역시 송파구 양재천47가 (준영이마을) sub : 천광역시 송파구 ---  양재천47가 (준영이마을)
# /n 제주특별자치도 청주시 청원구 영동대로 sub : 주특별자치도 청주시 ---  청원구 영동대로
# /n 경상북도 영월군 오금로 sub : 상북도 영월군 ---  오금로
# /n 충청북도 수원시 영통구 백제고분385거리 (성현신읍) sub : 청북도 수원시 ---  영통구 백제고분385거리 (성현신읍)
# /n 충청북도 부천시 원미구 개포4길 sub : 청북도 부천시 ---  원미구 개포4길
# /n 울산광역시 성동구 가락가 (지아김읍) sub : 산광역시 성동구 ---  가락가 (지아김읍)
# /n 전라북도 용인시 수지구 삼성거리 (종수이리) sub : 라북도 용인시 ---  수지구 삼성거리 (종수이리)
# /n 부산광역시 용산구 잠실거리 (미정김최동) sub : 산광역시 용산구 ---  잠실거리 (미정김최동)
# /n 전라남도 부천시 소사구 논현167길 (영수박읍) sub : 라남도 부천시 ---  소사구 논현167길 (영수박읍)
# /n 경상남도 화성시 석촌호수거리 (지현최마을) sub : 상남도 화성시 ---  석촌호수거리 (지현최마을)
# /n 충청북도 수원시 영통구 가락가 (은주장김읍) sub : 청북도 수원시 ---  영통구 가락가 (은주장김읍)
# /n 서울특별시 강동구 압구정로 sub : 울특별시 강동구 ---  압구정로
# /n 세종특별자치시 강북구 역삼104거리 sub : 종특별자치시 강북구 ---  역삼104거리
# /n 경상남도 양평군 삼성747길 sub : 상남도 양평군 ---  삼성747길
# /n 제주특별자치도 수원시 권선구 역삼로 sub : 주특별자치도 수원시 ---  권선구 역삼로
# /n 경기도 진천군 역삼9길 (미정김박읍) sub : 기도 진천군 ---  역삼9길 (미정김박읍)
# /n 광주광역시 은평구 영동대159거리 (성진송면) sub : 주광역시 은평구 ---  영동대159거리 (성진송면)
# /n 세종특별자치시 중랑구 역삼거리 sub : 종특별자치시 중랑구 ---  역삼거리
# /n 대전광역시 영등포구 학동36로 (시우우마을) sub : 전광역시 영등포구 ---  학동36로 (시우우마을)
# /n 광주광역시 동작구 봉은사655로 (성민김양면) sub : 주광역시 동작구 ---  봉은사655로 (성민김양면)
# /n 대전광역시 강남구 강남대길 sub : 전광역시 강남구 ---  강남대길
# /n 전라남도 용인시 수지구 압구정0길 sub : 라남도 용인시 ---  수지구 압구정0길
# /n 세종특별자치시 서구 압구정길 (예진이최읍) sub : 종특별자치시 서구 ---  압구정길 (예진이최읍)
# /n 광주광역시 도봉구 서초대로 sub : 주광역시 도봉구 ---  서초대로
# /n 울산광역시 용산구 영동대8길 sub : 산광역시 용산구 ---  영동대8길
# /n 경상북도 충주시 가락50길 sub : 상북도 충주시 ---  가락50길
# /n 충청북도 의정부시 언주로 (서현신임면) sub : 청북도 의정부시 ---  언주로 (서현신임면)
# /n 제주특별자치도 동두천시 영동대2거리 sub : 주특별자치도 동두천시 ---  영동대2거리
# /n 부산광역시 강북구 선릉2거리 sub : 산광역시 강북구 ---  선릉2거리
# /n 충청남도 청주시 서원구 도산대길 (예준서마을) sub : 청남도 청주시 ---  서원구 도산대길 (예준서마을)
# /n 대전광역시 성동구 양재천44길 (승민김동) sub : 전광역시 성동구 ---  양재천44길 (승민김동)
# /n 충청남도 하남시 삼성가 sub : 청남도 하남시 ---  삼성가
# /n 인천광역시 마포구 봉은사3거리 (서준안면) sub : 천광역시 마포구 ---  봉은사3거리 (서준안면)
# /n 충청남도 청양군 역삼길 sub : 청남도 청양군 ---  역삼길
# /n 경기도 양구군 도산대679가 sub : 기도 양구군 ---  도산대679가
# /n 울산광역시 서대문구 역삼48거리 (은경김김동) sub : 산광역시 서대문구 ---  역삼48거리 (은경김김동)
# /n 울산광역시 구로구 백제고분863길 sub : 산광역시 구로구 ---  백제고분863길
# /n 경기도 성남시 중원구 언주187거리 (승현한허면) sub : 기도 성남시 ---  중원구 언주187거리 (승현한허면)
# /n 부산광역시 강남구 반포대53가 sub : 산광역시 강남구 ---  반포대53가
# /n 대전광역시 성동구 오금거리 (중수조이리) sub : 전광역시 성동구 ---  오금거리 (중수조이리)
# /n 충청북도 고양시 일산동구 역삼가 (민수민동) sub : 청북도 고양시 ---  일산동구 역삼가 (민수민동)
# /n 서울특별시 동대문구 역삼48로 (채원김이리) sub : 울특별시 동대문구 ---  역삼48로 (채원김이리)
# /n 강원도 의왕시 가락로 sub : 원도 의왕시 ---  가락로
# /n 충청남도 춘천시 도산대가 (광수남면) sub : 청남도 춘천시 ---  도산대가 (광수남면)
# /n 경상북도 청양군 강남대길 (영순김이동) sub : 상북도 청양군 ---  강남대길 (영순김이동)
# /n 세종특별자치시 북구 강남대29길 (정수김면) sub : 종특별자치시 북구 ---  강남대29길 (정수김면)
# /n 경기도 영동군 서초대2로 (준서안읍) sub : 기도 영동군 ---  서초대2로 (준서안읍)
# /n 경상남도 평택시 서초중앙거리 (준호고김읍) sub : 상남도 평택시 ---  서초중앙거리 (준호고김읍)
# /n 전라북도 광명시 양재천29거리 sub : 라북도 광명시 ---  양재천29거리
# /n 경상북도 고양시 일산동구 압구정가 (영숙김마을) sub : 상북도 고양시 ---  일산동구 압구정가 (영숙김마을)
# /n 인천광역시 강북구 서초중앙거리 sub : 천광역시 강북구 ---  서초중앙거리
# /n 광주광역시 광진구 양재천661거리 sub : 주광역시 광진구 ---  양재천661거리
# /n 충청남도 청주시 서원구 반포대로 (정훈이동) sub : 청남도 청주시 ---  서원구 반포대로 (정훈이동)
# /n 부산광역시 남구 백제고분로 sub : 산광역시 남구 ---  백제고분로
# /n 대구광역시 금천구 양재천로 sub : 구광역시 금천구 ---  양재천로
# /n 경상북도 남양주시 테헤란가 sub : 상북도 남양주시 ---  테헤란가
# /n 경상남도 하남시 영동대가 (영호이면) sub : 상남도 하남시 ---  영동대가 (영호이면)
# /n 대구광역시 관악구 삼성가 (숙자이김리) sub : 구광역시 관악구 ---  삼성가 (숙자이김리)
# /n 제주특별자치도 안산시 단원구 개포559가 (현준우조면) sub : 주특별자치도 안산시 ---  단원구 개포559가 (현준우조면)
# /n 울산광역시 영등포구 서초대215거리 sub : 산광역시 영등포구 ---  서초대215거리
# /n 경상남도 홍성군 역삼로 sub : 상남도 홍성군 ---  역삼로
# /n 전라남도 연천군 가락거리 (현지이이읍) sub : 라남도 연천군 ---  가락거리 (현지이이읍)
# /n 충청북도 삼척시 석촌호수8거리 sub : 청북도 삼척시 ---  석촌호수8거리
# /n 전라북도 광주시 언주136가 (재현이면) sub : 라북도 광주시 ---  언주136가 (재현이면)
# /n 대구광역시 서구 삼성길 (경수주박면) sub : 구광역시 서구 ---  삼성길 (경수주박면)
# /n 대전광역시 남구 강남대로 sub : 전광역시 남구 ---  강남대로
# /n 대전광역시 중랑구 학동거리 sub : 전광역시 중랑구 ---  학동거리
# /n 서울특별시 양천구 개포9가 sub : 울특별시 양천구 ---  개포9가
# /n 세종특별자치시 은평구 가락34로 (민지노리) sub : 종특별자치시 은평구 ---  가락34로 (민지노리)
# /n 대구광역시 은평구 압구정4로 sub : 구광역시 은평구 ---  압구정4로
# /n 강원도 청주시 서원구 논현2로 (은정김박동) sub : 원도 청주시 ---  서원구 논현2로 (은정김박동)
# /n 경상남도 서천군 영동대205길 (민지강마을) sub : 상남도 서천군 ---  영동대205길 (민지강마을)
# /n 부산광역시 금천구 개포18거리 (명숙최박리) sub : 산광역시 금천구 ---  개포18거리 (명숙최박리)
# /n 인천광역시 북구 삼성540길 sub : 천광역시 북구 ---  삼성540길
# /n 세종특별자치시 구로구 가락081가 sub : 종특별자치시 구로구 ---  가락081가
# /n 서울특별시 은평구 개포거리 sub : 울특별시 은평구 ---  개포거리
# /n 광주광역시 중랑구 오금길 sub : 주광역시 중랑구 ---  오금길
# /n 인천광역시 동구 강남대862로 sub : 천광역시 동구 ---  강남대862로
# /n 서울특별시 송파구 영동대길 sub : 울특별시 송파구 ---  영동대길
# /n 제주특별자치도 화성시 반포대거리 (현주배오면) sub : 주특별자치도 화성시 ---  반포대거리 (현주배오면)
# /n 대구광역시 은평구 선릉길 (승현이면) sub : 구광역시 은평구 ---  선릉길 (승현이면)
# /n 경기도 김포시 개포로 (영자한마을) sub : 기도 김포시 ---  개포로 (영자한마을)
# /n 강원도 화성시 역삼7가 (서영이마을) sub : 원도 화성시 ---  역삼7가 (서영이마을)
# /n 울산광역시 북구 논현523가 (현준오한동) sub : 산광역시 북구 ---  논현523가 (현준오한동)
# /n 경기도 당진시 잠실거리 sub : 기도 당진시 ---  잠실거리
# /n 부산광역시 광진구 영동대52로 (순옥심박마을) sub : 산광역시 광진구 ---  영동대52로 (순옥심박마을)
# /n 대전광역시 남구 언주길 sub : 전광역시 남구 ---  언주길
# /n 대전광역시 강북구 백제고분가 (주원류동) sub : 전광역시 강북구 ---  백제고분가 (주원류동)
# /n 전라북도 부천시 원미구 강남대길 (재호이전면) sub : 라북도 부천시 ---  원미구 강남대길 (재호이전면)
# /n 강원도 부천시 소사구 봉은사길 (미숙박리) sub : 원도 부천시 ---  소사구 봉은사길 (미숙박리)
# /n 광주광역시 동작구 영동대길 (성진박동) sub : 주광역시 동작구 ---  영동대길 (성진박동)
# /n 경상남도 고양시 일산동구 반포대로 (영순이읍) sub : 상남도 고양시 ---  일산동구 반포대로 (영순이읍)
# /n 세종특별자치시 중구 서초중앙970가 (미경전면) sub : 종특별자치시 중구 ---  서초중앙970가 (미경전면)
# /n 세종특별자치시 동대문구 선릉길 (수민박구읍) sub : 종특별자치시 동대문구 ---  선릉길 (수민박구읍)
# /n 부산광역시 중구 개포7길 (성민전이리) sub : 산광역시 중구 ---  개포7길 (성민전이리)
# /n 인천광역시 서초구 백제고분거리 (예은최황리) sub : 천광역시 서초구 ---  백제고분거리 (예은최황리)
# /n 울산광역시 종로구 테헤란가 (지아김김읍) sub : 산광역시 종로구 ---  테헤란가 (지아김김읍)
# /n 충청남도 평창군 오금6길 (미정이마을) sub : 청남도 평창군 ---  오금6길 (미정이마을)
# /n 인천광역시 용산구 잠실879길 sub : 천광역시 용산구 ---  잠실879길
# /n 부산광역시 영등포구 오금5가 sub : 산광역시 영등포구 ---  오금5가
# /n 대구광역시 중구 가락로 sub : 구광역시 중구 ---  가락로
# /n 세종특별자치시 강서구 테헤란38거리 (주원김이마을) sub : 종특별자치시 강서구 ---  테헤란38거리 (주원김이마을)
# /n 대전광역시 구로구 논현거리 sub : 전광역시 구로구 ---  논현거리
# /n 경상북도 서천군 오금0로 (경수유박마을) sub : 상북도 서천군 ---  오금0로 (경수유박마을)
# /n 광주광역시 남구 서초중앙33가 sub : 주광역시 남구 ---  서초중앙33가
# /n 대전광역시 중랑구 언주길 sub : 전광역시 중랑구 ---  언주길
# /n 경상남도 옥천군 압구정2로 (예원김김면) sub : 상남도 옥천군 ---  압구정2로 (예원김김면)
# /n 대구광역시 영등포구 서초대가 (재호김안마을) sub : 구광역시 영등포구 ---  서초대가 (재호김안마을)
